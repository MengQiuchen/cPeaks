# %%
source('../../source/basic.r')

source('../validataion.r')
# Out:
# Warning message:
# “no function found corresponding to methods exports from ‘BSgenome’ for: ‘releaseName’”

# %%
suppressPackageStartupMessages({
    library(tidyverse)
    library(Signac)
    library(Seurat)
    library(GenomeInfoDb)
    library(EnsDb.Hsapiens.v86 )# hg38
   # library(EnsDb.Hsapiens.v75) #hg19
    library(ggplot2)
    library(patchwork)
    library(data.table)
    library(Matrix)
    set.seed(1234)
})

# %% [markdown]
# # cpeak data

# %% [markdown]
# ## read data

# %%
sample_name='3BAE2L'

# %%
dir_mtx = list.files('data/',pattern = 'gz.mtx')%>%.[grep(sample_name,.)]

# %%
frag_dir = list.files('data/',pattern = 'gz$')%>%.[grep(sample_name,.)]

# %%
counts <- readMM("data/GSM5276951_3BAE2L_ATAC_fragments.tsv.gz.mtx")

# %%
counts%>%dim
# Out:
# [1] 1568814    8014

# %%
colnames(counts) <- fread('data/barcode/3BAE2L.barcode',header = FALSE)%>%
                    pull(V1)

rownames(counts) <- fread('data/cpeak.bed')%>%mutate(name=paste0(V1,':',V2,'-',V3))%>%pull(name)

# %%
counts[1:3,1:3]
# Out:
# 3 x 3 sparse Matrix of class "dgTMatrix"
#                  TCAAAGCTCCGGCGAT-1 TCACCTGGTTAGGCTT-1 CTAGGATTCCCAGTAA-1
# chr1:9919-10727                   .                  .                  .
# chr1:11043-11422                  .                  .                  .
# chr1:13249-13832                  .                  .                  .

# %%
metadata <- fread('data/tumor_metadata_Full_Cohort.tsv')

# %%
metadata%>%dim
# Out:
# [1] 74621    20

# %%
colnames(metadata)
# Out:
#  [1] "Barcode"              "Sample"               "TSSEnrichment"
#  [4] "ReadsInTSS"           "ReadsInPromoter"      "ReadsInBlacklist"
#  [7] "PromoterRatio"        "PassQC"               "NucleosomeRatio"
# [10] "nMultiFrags"          "nMonoFrags"           "nFrags"
# [13] "nDiFrags"             "DoubletScore"         "DoubletEnrichment"
# [16] "BlacklistRatio"       "ATAC_clusters"        "predictedCell_ArchR"
# [19] "predictedGroup_ArchR" "predictedScore_ArchR"

# %%
metadata$Sample%>%unique
# Out:
#  [1] "3533EL" "3571DL" "36186L" "36639L" "366C5L" "37EACL" "38FE7L" "3BAE2L"
#  [9] "3CCF1L" "3E4D1L" "3E5CFL"

# %%
metadata = metadata%>%dplyr::filter(Sample==sample_name)%>%
        mutate(Barcode=str_extract(Barcode,'(?<=#).*'))%>%
        column_to_rownames('Barcode')

# %%
metadata%>%colnames
# Out:
#  [1] "Sample"               "TSSEnrichment"        "ReadsInTSS"
#  [4] "ReadsInPromoter"      "ReadsInBlacklist"     "PromoterRatio"
#  [7] "PassQC"               "NucleosomeRatio"      "nMultiFrags"
# [10] "nMonoFrags"           "nFrags"               "nDiFrags"
# [13] "DoubletScore"         "DoubletEnrichment"    "BlacklistRatio"
# [16] "ATAC_clusters"        "predictedCell_ArchR"  "predictedGroup_ArchR"
# [19] "predictedScore_ArchR"

# %%
metadata%>%head
# Out:
#                    Sample TSSEnrichment ReadsInTSS ReadsInPromoter
# TCAAAGCTCCGGCGAT-1 3BAE2L 8.113         17679      21802
# TCACCTGGTTAGGCTT-1 3BAE2L 8.202         16308      20357
# CTAGGATTCCCAGTAA-1 3BAE2L 5.828         10758      15264
# GCATTCCAGCCATTCA-1 3BAE2L 8.937         19528      24050
# GCACGGTGTGATAACA-1 3BAE2L 9.837         20085      23328
# GGATAGGCACAGTAGG-1 3BAE2L 9.161         19709      24214
#                    ReadsInBlacklist PromoterRatio PassQC NucleosomeRatio
# TCAAAGCTCCGGCGAT-1  954             0.11110658    1      1.639149
# TCACCTGGTTAGGCTT-1  949             0.10447738    1      1.298580
# CTAGGATTCCCAGTAA-1 1065             0.07903648    1      2.152975
# GCATTCCAGCCATTCA-1  824             0.12501949    1      1.787890
# GCACGGTGTGATAACA-1  928             0.12233596    1      1.073958
# GGATAGGCACAGTAGG-1  936             0.12802563    1      1.308483
#                    nMultiFrags nMonoFrags nFrags nDiFrags DoubletScore
# TCAAAGCTCCGGCGAT-1 10032       37176      98113  50905    0
# TCACCTGGTTAGGCTT-1  6515       42384      97423  48524    0
# CTAGGATTCCCAGTAA-1 11847       30626      96563  54090    0
# GCATTCCAGCCATTCA-1 11890       34501      96185  49794    0
# GCACGGTGTGATAACA-1  4836       45972      95344  44536    0
# GGATAGGCACAGTAGG-1  7561       40965      94567  46041    0
#                    DoubletEnrichment BlacklistRatio ATAC_clusters
# TCAAAGCTCCGGCGAT-1 0.14464534        0.004861741    C36
# TCACCTGGTTAGGCTT-1 0.53407510        0.004870513    C36
# CTAGGATTCCCAGTAA-1 0.07788595        0.005514535    C36
# GCATTCCAGCCATTCA-1 0.22253129        0.004283412    C36
# GCACGGTGTGATAACA-1 0.42280946        0.004866588    C35
# GGATAGGCACAGTAGG-1 0.02225313        0.004948872    C35
#                    predictedCell_ArchR  predictedGroup_ArchR
# TCAAAGCTCCGGCGAT-1 GAAACCTGTTCGGTTA-1_8 10-Epithelial cell
# TCACCTGGTTAGGCTT-1 TGATGCAAGTATGAAC-1_8 10-Epithelial cell
# CTAGGATTCCCAGTAA-1 GCGTGCATCGCGAAGA-1_8 10-Epithelial cell
# GCATTCCAGCCATTCA-1 CTGCAGGAGAGTGTGC-1_8 10-Epithelial cell
# GCACGGTGTGATAACA-1 GGGTAGAAGCCTTGAT-1_8 10-Epithelial cell
# GGATAGGCACAGTAGG-1 TTTACGTCAGACCAGA-1_8 10-Epithelial cell
#                    predictedScore_ArchR
# TCAAAGCTCCGGCGAT-1 1
# TCACCTGGTTAGGCTT-1 1
# CTAGGATTCCCAGTAA-1 1
# GCATTCCAGCCATTCA-1 1
# GCACGGTGTGATAACA-1 1
# GGATAGGCACAGTAGG-1 1

# %% [markdown]
# ### subset using metadata

# %%
counts.sub <- counts[,intersect(rownames(metadata),colnames(counts))]

# %%
metadata.sub <- metadata[intersect(rownames(metadata),colnames(counts)),]

# %% [markdown]
# ## build seurat object

# %%
chrom_assay <- CreateChromatinAssay(
  counts = counts.sub,
  sep = c(":", "-"),
  genome = 'hg38',
  fragments = './data/GSM5276951_3BAE2L_ATAC_fragments.tsv.gz',
  min.cells = 0,
  min.features = 0
)
# Out:
# Warning message in CreateChromatinAssay(counts = counts.sub, sep = c(":", "-"), :
# "Overlapping ranges supplied. Ranges should be non-overlapping."
# Computing hash

# %%
seurat.object.all <- CreateSeuratObject(
  counts = chrom_assay,
  assay = "peaks",
  meta.data = metadata.sub
)
# Out:
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from peaks to peaks_"

# %%
seurat.object.all
# Out:
# An object of class Seurat
# 1568814 features across 8014 samples within 1 assay
# Active assay: peaks (1568814 features, 0 variable features)

# %%
seurat.object <- subset(seurat.object.all, cells = rownames(metadata.sub))

# %%
seurat.object
# Out:
# An object of class Seurat
# 1568814 features across 8014 samples within 1 assay
# Active assay: peaks (1568814 features, 0 variable features)

# %%
seurat.object <- RunTFIDF(seurat.object)
seurat.object <- FindTopFeatures(seurat.object, min.cutoff = 'q0')
seurat.object <- RunSVD(seurat.object)
# Out:
# Performing TF-IDF normalization
#
# Warning message in RunTFIDF.default(object = GetAssayData(object = object, slot = "counts"), :
# "Some features contain 0 total counts"
# Running SVD
#
# Scaling cell embeddings

# %%
psize(4,4)

# %%
DepthCor(seurat.object)
# Out:
# plot without title

# %%
suppressMessages({
    
    seurat.object <- RunUMAP(object = seurat.object, reduction = 'lsi', dims = 2:30)
    seurat.object <- FindNeighbors(object = seurat.object, reduction = 'lsi', dims = 2:30)
    seurat.object <- FindClusters(object = seurat.object, verbose = FALSE, algorithm = 3)
    # p.umap.cluster = DimPlot(object = seurat.object, label = TRUE) + NoLegend()
    
})
# Out:
# Warning message:
# "The default method for RunUMAP has changed from calling Python UMAP via reticulate to the R-native UWOT using the cosine metric
# To use Python UMAP via reticulate, set umap.method to 'umap-learn' and metric to 'correlation'
# This message will be shown once per session"

# %%
p.umap.cluster = DimPlot(object = seurat.object, label = TRUE) + NoLegend()

# %%
psize()

# %%
p.umap.cluster
# Out:
# plot without title

# %%
cells.sub <- metadata.sub%>%rownames_to_column('cell')%>%group_by(predictedGroup_ArchR)%>%
            mutate(n=n())%>%ungroup%>% dplyr::filter(n>100)%>%pull(cell)

# %%
seurat.object@reductions$umap

# %%
p.umap.label = DimPlot(object = seurat.object,cells = cells.sub, group.by='predictedGroup_ArchR',label = TRUE) + NoLegend()

# %%
psize(6,6)

# %%
p.umap.label #+ scale_color_manual(values = rep(colors_,2))
# Out:
# plot without title

# %%
metadata.sub%>%pull(predictedGroup_ArchR)%>%unique
# Out:
#  [1] "10-Epithelial cell"    "1-Endothelia"          "5-Macrophage"
#  [4] "20-Ciliated"           "2-T cell"              "24-Fibroblast"
#  [7] "28-B cell"             "26-Fibroblast"         "6-Fibroblast"
# [10] "4-Lymphocytes"         "13-Macrophages"        "30-T cell"
# [13] "25-Fibroblast"         "18-Fibroblast"         "7-Smooth muscle cells"

# %% [markdown]
# # save

# %%
save.image('image/fw8.image')

# %%
seurat.objct.list <- list(peaks=seurat.object, cpeaks=seurat.object.cpeak)

# %%
qsave(seurat.objct.list,'rds/fw8.seurat.objct.list.qs')

# %%
psize(6,6)

# %%
p.umap.cluster+theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
ggsave(paste0('plot/fw8.peak.umpa.cluster.pdf'),height = 6,width = 6)

# %%
p.umap.label+theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
ggsave(paste0('plot/fw8.peak.umpa.label.pdf'),height = 6,width = 6)

# %%
p.umap.cluster.cpeak+theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
ggsave(paste0('plot/fw8.cpeak.umpa.cluster.pdf'),height = 6,width = 6)

# %%
p.umap.label.cpeak+theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
ggsave(paste0('plot/fw8.cpeak.umpa.label.pdf'),height = 6,width = 6)
