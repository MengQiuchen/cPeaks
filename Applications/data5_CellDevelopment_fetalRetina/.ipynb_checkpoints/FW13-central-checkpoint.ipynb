# %%
source('../../source/basic.r')

source('../validataion.r')
# Out:
# Warning message:
# “no function found corresponding to methods exports from ‘BSgenome’ for: ‘releaseName’”

# %%
suppressPackageStartupMessages({
    library(tidyverse)
    library(Signac)
    library(Seurat)
    library(GenomeInfoDb)
    library(EnsDb.Hsapiens.v86 )# hg38
   # library(EnsDb.Hsapiens.v75) #hg19
    library(ggplot2)
    library(patchwork)
    library(data.table)
    library(Matrix)
    set.seed(1234)
})

# %% [markdown]
# # peak data

# %% [markdown]
# ## read data

# %%
counts <- readMM("data/d89C_fetal_filtered_peak_bc_matrix//matrix.mtx")

# %%
counts%>%dim
# Out:
# [1] 298835   8050

# %%
colnames(counts) <- fread('data/d89C_fetal_filtered_peak_bc_matrix/barcodes.tsv',header = FALSE)%>%
                    pull(V1)

rownames(counts) <- fread('data/d89C_fetal_filtered_peak_bc_matrix/peaks.bed')%>%mutate(name=paste0(V1,':',V2,'-',V3))%>%pull(name)

# %%
counts[1:3,1:3]
# Out:
# 3 x 3 sparse Matrix of class "dgTMatrix"
#                    AAACGAAAGAAATACC-1 AAACGAAAGAGACTCG-1 AAACGAAAGCAGAAAG-1
# chr1:108969-109397                  .                  .                  .
# chr1:181270-181720                  .                  .                  .
# chr1:190651-191785                  .                  .                  .

# %%
metadata <- fread('data/raw/GSM5585611_d89C_fetal_metadata.csv.gz')

# %%
metadata%>%dim
# Out:
# [1] 6438   34

# %% [markdown]
# ### subset using metadata

# %%
counts.sub <- counts[,intersect(metadata$V1,colnames(counts))]

# %%
counts.sub[1:3,1:3]
# Out:
# 3 x 3 sparse Matrix of class "dgTMatrix"
#                    TTGAGTGCATAGCAGG-1 AGGCCTGTCCGGCGAT-1 AGGCGAAGTGCGTAGA-1
# chr1:108969-109397                  2                  2                  2
# chr1:181270-181720                  .                  .                  .
# chr1:190651-191785                  .                  .                  .

# %%
metadata.sub <- metadata%>%dplyr::filter(V1%in%intersect(metadata$V1,colnames(counts)))%>%column_to_rownames('V1')

# %% [markdown]
# ## build seurat object

# %%
chrom_assay <- CreateChromatinAssay(
  counts = counts.sub,
  sep = c(":", "-"),
  genome = 'hg38',
  fragments = './data/fragments/GSM5585611_d89C_fetal_fragments.tsv.gz',
  min.cells = 0,
  min.features = 0
)
# Out:
# Computing hash

# %%
seurat.object.all <- CreateSeuratObject(
  counts = chrom_assay,
  assay = "peaks",
  meta.data = metadata.sub
)
# Out:
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from peaks to peaks_"

# %%
seurat.object.all
# Out:
# An object of class Seurat
# 298835 features across 6438 samples within 1 assay
# Active assay: peaks (298835 features, 0 variable features)

# %%
seurat.object <- subset(seurat.object.all, cells = rownames(metadata.sub))

# %%
seurat.object
# Out:
# An object of class Seurat
# 298835 features across 6438 samples within 1 assay
# Active assay: peaks (298835 features, 0 variable features)

# %%
seurat.object <- RunTFIDF(seurat.object)
seurat.object <- FindTopFeatures(seurat.object, min.cutoff = 'q0')
seurat.object <- RunSVD(seurat.object)
# Out:
# Performing TF-IDF normalization
#
# Warning message in RunTFIDF.default(object = GetAssayData(object = object, slot = "counts"), :
# "Some features contain 0 total counts"
# Running SVD
#
# Scaling cell embeddings

# %%
psize(4,4)

# %%
DepthCor(seurat.object)
# Out:
# plot without title

# %%
suppressMessages({
    
    seurat.object <- RunUMAP(object = seurat.object, reduction = 'lsi', dims = 2:30)
    seurat.object <- FindNeighbors(object = seurat.object, reduction = 'lsi', dims = 2:30)
    seurat.object <- FindClusters(object = seurat.object, verbose = FALSE, algorithm = 3)
    # p.umpa.cluster = DimPlot(object = seurat.object, label = TRUE) + NoLegend()
    
})
# Out:
# Warning message:
# "The default method for RunUMAP has changed from calling Python UMAP via reticulate to the R-native UWOT using the cosine metric
# To use Python UMAP via reticulate, set umap.method to 'umap-learn' and metric to 'correlation'
# This message will be shown once per session"

# %%
p.umpa.cluster = DimPlot(object = seurat.object, label = TRUE) + NoLegend()

# %%
psize()

# %%
p.umpa.cluster
# Out:
# plot without title

# %%
p.umpa.label = DimPlot(object = seurat.object,group.by='type',label = TRUE) + NoLegend()

# %%
psize(6,6)

# %%
p.umpa.label
# Out:
# plot without title

# %% [markdown]
# # cPeaks

# %% [markdown]
# ## read data

# %%
counts <- readMM("data/d89C_fetal_filtered_peak_bc_matrix//matrix.cpeak.mtx")

# %%
counts%>%dim
# Out:
# [1] 1568814    8050

# %%
colnames(counts) <- fread('data/d89C_fetal_filtered_peak_bc_matrix/barcodes.tsv',header = FALSE)%>%
                    pull(V1)

rownames(counts) <- fread('data/cpeak.bed')%>%mutate(name=paste0(V1,':',V2,'-',V3))%>%pull(name)

# %%
counts[1:3,1:3]
# Out:
# 3 x 3 sparse Matrix of class "dgTMatrix"
#                  AAACGAAAGAAATACC-1 AAACGAAAGAGACTCG-1 AAACGAAAGCAGAAAG-1
# chr1:9919-10727                   .                  .                  .
# chr1:11043-11422                  .                  .                  .
# chr1:13249-13832                  .                  .                  .

# %% [markdown]
# ### subset using metadata

# %%
counts.sub <- counts[,intersect(metadata$V1,colnames(counts))]

# %%
counts.sub[1:3,1:3]
# Out:
# 3 x 3 sparse Matrix of class "dgTMatrix"
#                  TTGAGTGCATAGCAGG-1 AGGCCTGTCCGGCGAT-1 AGGCGAAGTGCGTAGA-1
# chr1:9919-10727                   .                  .                  .
# chr1:11043-11422                  .                  .                  .
# chr1:13249-13832                  .                  .                  .

# %%
metadata.sub <- metadata%>%dplyr::filter(V1%in%intersect(metadata$V1,colnames(counts)))%>%column_to_rownames('V1')

# %% [markdown]
# ## build seurat object

# %%
chrom_assay <- CreateChromatinAssay(
  counts = counts.sub,
  sep = c(":", "-"),
  genome = 'hg38',
  fragments = './data/fragments/GSM5585611_d89C_fetal_fragments.tsv.gz',
  min.cells = 10,
  min.features = 0
)
# Out:
# Warning message in CreateChromatinAssay(counts = counts.sub, sep = c(":", "-"), :
# "Overlapping ranges supplied. Ranges should be non-overlapping."
# Computing hash

# %%
seurat.object.cpeak.all <- CreateSeuratObject(
  counts = chrom_assay,
  assay = "peaks",
  meta.data = metadata.sub
)
# Out:
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from peaks to peaks_"

# %%
seurat.object.cpeak.all
# Out:
# An object of class Seurat
# 287651 features across 6438 samples within 1 assay
# Active assay: peaks (287651 features, 0 variable features)

# %%
seurat.object.cpeak <- subset(seurat.object.cpeak.all, cells = rownames(metadata.sub))

# %%
seurat.object.cpeak
# Out:
# An object of class Seurat
# 287651 features across 6438 samples within 1 assay
# Active assay: peaks (287651 features, 0 variable features)

# %%
seurat.object.cpeak <- RunTFIDF(seurat.object.cpeak)
seurat.object.cpeak <- FindTopFeatures(seurat.object.cpeak, min.cutoff = 'q0')
# Out:
# Performing TF-IDF normalization

# %%
seurat.object.cpeak <- RunSVD(seurat.object.cpeak)
# Out:
# Running SVD
#
# Scaling cell embeddings

# %%
psize(4,4)

# %%
DepthCor(seurat.object.cpeak)
# Out:
# plot without title

# %%
suppressMessages({
    
    seurat.object.cpeak <- RunUMAP(object = seurat.object.cpeak, reduction = 'lsi', dims = 2:30)
    seurat.object.cpeak <- FindNeighbors(object = seurat.object.cpeak, reduction = 'lsi', dims = 2:30)
    seurat.object.cpeak <- FindClusters(object = seurat.object.cpeak, verbose = FALSE, algorithm = 3)
    # p.umpa.cluster = DimPlot(object = seurat.object, label = TRUE) + NoLegend()
    
})

# %%
p.umpa.cluster.cpeak = DimPlot(object = seurat.object.cpeak, label = TRUE) + NoLegend()

# %%
psize()

# %%
p.umpa.cluster.cpeak
# Out:
# plot without title

# %%
p.umpa.label.cpeak = DimPlot(object = seurat.object.cpeak,group.by='type',label = TRUE) + NoLegend()

# %%
psize(6,6)

# %%
p.umpa.label.cpeak
# Out:
# plot without title

# %% [markdown]
# # save

# %%
save.image('image/fw13-c.image')

# %%
seurat.objct.list <- list(peaks=seurat.object, cpeaks=seurat.object.cpeak)

# %%
qsave(seurat.objct.list,'rds/fw13c.seurat.objct.list.qs')

# %%
psize(6,6)

# %%
p.umpa.cluster+theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
ggsave(paste0('plot/fw13c.peak.umpa.cluster.pdf'),height = 6,width = 6)

# %%
p.umpa.label+theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
ggsave(paste0('plot/fw13c.peak.umpa.label.pdf'),height = 6,width = 6)

# %%
p.umpa.cluster.cpeak+theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
ggsave(paste0('plot/fw13c.cpeak.umpa.cluster.pdf'),height = 6,width = 6)

# %%
p.umpa.label.cpeak+theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
ggsave(paste0('plot/fw13c.cpeak.umpa.label.pdf'),height = 6,width = 6)
